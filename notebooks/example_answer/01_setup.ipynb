# %%
# %run ./00_config

# %% [markdown]
# ## 事前準備
#
# カタログ・スキーマ・ボリュームの作成

# %%
# カタログを作成
spark.sql(
    f"""
    CREATE CATALOG IF NOT EXISTS {catalog_name}
    """
)

# スキーマを作成
spark.sql(
    f"""
    CREATE SCHEMA IF NOT EXISTS {catalog_name}.{schema_name}
    """
)

# ボリュームを作成
spark.sql(
    f"""
    CREATE VOLUME IF NOT EXISTS {catalog_name}.{schema_name}.{raw_data_volume_name}
    """
)

# %%
# Auto Loaderで使うチェックポイントボリュームを作成
print(f"checkpoint_volume_name: `{checkpoint_volume_name}`")
spark.sql(
    f"""
    CREATE VOLUME IF NOT EXISTS {catalog_name}.{schema_name}.{checkpoint_volume_name}
    """
)
