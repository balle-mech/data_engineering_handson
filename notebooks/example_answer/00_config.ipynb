# %%
# 利用するカタログ名を設定
catalog_name = "my_lab"
schema_name = "handson"

# テーブル名を設定
bronze_table_name = "bronze_audit"
bronze_table_path = f"{catalog_name}.{schema_name}.{bronze_table_name}"
silver_table_name = "silver_audit"
silver_table_path = f"{catalog_name}.{schema_name}.{silver_table_name}"

# ソースファイルを配置する Volume 名を設定
src_csv_volume_name = "unit_mtg_handson"
audit_csv_path = f"/Volumes/{catalog_name}/{schema_name}/{src_csv_volume_name}/audit"
usage_csv_path = f"/Volumes/{catalog_name}/{schema_name}/{src_csv_volume_name}/usage"

# チェックポイントボリューム
checkpoint_volume_name = "checkpoint_volume_01"
checkpoint_volume_path = f"/Volumes/{catalog_name}/{schema_name}/{checkpoint_volume_name}"

# %%
print("catalog_name: " + catalog_name)
print("schema_name: " + schema_name)
print("bronze_table_path: " + bronze_table_path)
print("silver_table_path:" + silver_table_path)
print("audit_csv_path: " + audit_csv_path)
print("usage_csv_path: " + usage_csv_path)
print("checkpoint_volume_path: " + checkpoint_volume_path)
